# %% [markdown]
# <a href="https://colab.research.google.com/github/raviteja10096/PythonBasics/blob/main/python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Intro

# %% [markdown]
# ## Series

# %%
pip install pandas

# %% [markdown]
# ![Screenshot 2024-01-03 at 10.07.22 AM.png](data:image/png;base64,...)

# %%
import pandas as pd

lst = [1,3,5,7,9, "MAD"]

pd.Series(lst)
# Out:
# 0      1
# 1      3
# 2      5
# 3      7
# 4      9
# 5    MAD
# dtype: object

# %%
empDict = {"Jane":90,"Mary":86,"Bill":80,"Tom":65,"Tim":100}

empDict

a1 = pd.Series(empDict)

a1/100
# Out:
# Jane    0.90
# Mary    0.86
# Bill    0.80
# Tom     0.65
# Tim     1.00
# dtype: float64

# %%
"Jane" in a1
# Out:
# True

# %%
#With the index argument, you can name your own labels.
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# ## DataFrame

# %%
data = {
  "names": ["Teja", "Ravi", "Niranjan"],
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       names  calories  duration
# 0      Teja       420        50
# 1      Ravi       380        40
# 2  Niranjan       390        45

# %%
df.columns
# Out:
# Index(['names', 'calories', 'duration'], dtype='object')

# %%
df["calories"]
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
#returns a specified number of last rows
df.tail(2)
# Out:
#       names  calories  duration
# 1      Ravi       380        40
# 2  Niranjan       390        45

# %%
# To sort the values
df.sort_values(by="names",ascending=True)
# Out:
#       names  calories  duration
# 2  Niranjan       390        45
# 1      Ravi       380        40
# 0      Teja       420        50

# %%
# To get stats of dataframe for Numerical data
df.describe()
# Out:
#          calories  duration
# count    3.000000       3.0
# mean   396.666667      45.0
# std     20.816660       5.0
# min    380.000000      40.0
# 25%    385.000000      42.5
# 50%    390.000000      45.0
# 75%    405.000000      47.5
# max    420.000000      50.0

# %%
# To get description of dataframe to include String methods as well
df.describe(include="all")
# Out:
#        names    calories  duration
# count      3    3.000000       3.0
# unique     3         NaN       NaN
# top     Teja         NaN       NaN
# freq       1         NaN       NaN
# mean     NaN  396.666667      45.0
# std      NaN   20.816660       5.0
# min      NaN  380.000000      40.0
# 25%      NaN  385.000000      42.5
# 50%      NaN  390.000000      45.0
# 75%      NaN  405.000000      47.5
# max      NaN  420.000000      50.0

# %%
# Accessing only specific column using loc
df
df.loc[2:,["names","duration"]]
# Out:
#       names  duration
# 2  Niranjan        45

# %%
# Accessing only specific column using iloc

df.iloc[2:,1:2]
# Out:
#    calories
# 2       390

# %%
#Adding New Column
df["age"]=[26,27,28]
df["extraColumn"]=[4,5,6]

# %%
df
# Out:
#       names  calories  duration  age  extraColumn
# 0      Teja       420        50   26            4
# 1      Ravi       380        40   27            5
# 2  Niranjan       390        45   28            6

# %%
#Dropping Column
df.drop("extraColumn",axis=1)
# Out:
#       names  calories  duration  age
# 0      Teja       420        50   26
# 1      Ravi       380        40   27
# 2  Niranjan       390        45   28

# %%
df
# Out:
#       names  calories  duration  age  extraColumn
# 0      Teja       420        50   26            4
# 1      Ravi       380        40   27            5
# 2  Niranjan       390        45   28            6

# %%
# as you see above column is not removed from original data frame
# to Update in Original dataframe use inPlace =true
df.drop("extraColumn",axis=1,inplace=True)

# %%
# post passin inplace=True we notice that "extraColumn" is removed
df
# Out:
#       names  calories  duration  age
# 0      Teja       420        50   26
# 1      Ravi       380        40   27
# 2  Niranjan       390        45   28

# %%
#concat

data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]}

data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'],
        'Age':[22, 32, 12, 52],
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]}

df = pd.DataFrame(data1,index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

print(df, "\n\n", df1)

# using a .concat() method
frames = [df, df1]

res1 = pd.concat(frames)
res1



#merge -> Joins
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 4  Gaurav   22  Allahabad           MCA    1000
# 5    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# ...

# %% [markdown]
# ### Concatenating dataframes

# %%
#Concatenating DataFrame by setting logic on axes :

df = pd.DataFrame(data1,index=[0, 1, 2, 3])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

res2 = pd.concat([df, df1], axis=1, join='inner')

res2
# Out:
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2  Gaurav   22  Allahabad           MCA         58  Gaurav   22  Allahabad
# 3    Anuj   32    Kannuaj           Phd         76    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
# union of dataframe
res2 = pd.concat([df, df1], axis=1, sort=False)

res2
# Out:
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 6     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN        NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           MCA  1000.0
# 3           Phd  2000.0
# 6          Bcom  3000.0
# 7        B.hons  4000.0

# %% [markdown]
# ### Merging DataFrame

# %%
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}


df = pd.DataFrame(data1)

df1 = pd.DataFrame(data2)


print(df, "\n\n", df1)
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons

# %%
# using .merge() function
res = pd.merge(df, df1, on='key')

res
# Out:
#   key key1_x    Name  Age key1_y    Address Qualification
# 0  K0     K0     Jai   27     K0     Nagpur         Btech
# 1  K1     K1  Princi   24     K0     Kanpur           B.A
# 2  K2     K0  Gaurav   22     K0  Allahabad          Bcom
# 3  K3     K1    Anuj   32     K0    Kannuaj        B.hons

# %%
# merging dataframe using multiple keys
res1 = pd.merge(df, df1, on=['key', 'key1'])

res1
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
# using keys from left frame
res = pd.merge(df, df1, how='left', on=['key', 'key1'])
res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN

# %%
# using keys from right frame
res1 = pd.merge(df, df1, how='right', on=['key', 'key1'])

res1
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# getting union  of keys
res2 = pd.merge(df, df1, how='outer', on=['key', 'key1'])

res2
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K1  Princi  24.0        NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K1    Anuj  32.0        NaN           NaN
# 4  K1   K0     NaN   NaN     Kanpur           B.A
# 5  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# getting intersection of keys
res3 = pd.merge(df, df1, how='inner', on=['key', 'key1'])

res3
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %% [markdown]
# ### Joining DataFrame

# %%
# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32]}

# Define a dictionary containing employee data
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])


print(df, "\n\n", df1)
# Out:
#       Name  Age
# K0     Jai   27
# K1  Princi   24
# K2  Gaurav   22
# K3    Anuj   32
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons

# %%
# joining dataframe
res = df.join(df1)

res
# Out:
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K1  Princi   24        NaN           NaN
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %%
# getting union
res1 = df.join(df1, how='outer')

res1
# Out:
#       Name   Age    Address Qualification
# K0     Jai  27.0  Allahabad           MCA
# K1  Princi  24.0        NaN           NaN
# K2  Gaurav  22.0    Kannuaj           Phd
# K3    Anuj  32.0  Allahabad          Bcom
# K4     NaN   NaN    Kannuaj        B.hons
